# %%
import pandas as pd
from cleverminer import cleverminer

# %%
data = pd.read_csv('crime_stations_transformed2.csv', sep=',')

df = pd.DataFrame(data)

## aby šel udělat right cut na datech, je potřeba jednotlivé kategorie nahradit číselnými hodnotami
df['Daytime_num'] = df['Daytime'].apply(lambda x: 1 if x == 'Early Morning' else (2 if x == 'Morning' else (3 if x=='Afternoon' else(4 if x=='Evening' else 5))))
df.head()
# Out:
#          CrimeDateTime        Description            Weapon Gender   Age  \
# 0  2013-09-05 06:30:00  LARCENY FROM AUTO  PERSONAL_WEAPONS      F  48.0
# 1  2013-09-05 21:00:00       AGG. ASSAULT             HANDS      F  11.0
# 2  2013-09-05 15:45:00     COMMON ASSAULT  PERSONAL_WEAPONS      M  22.0
# 3  2013-09-05 01:10:00            ROBBERY           FIREARM      F  23.0
# 4  2013-09-05 20:00:00           BURGLARY  PERSONAL_WEAPONS      M  27.0
#
#                         Race Old_District    Neighborhood PremiseType  \
# 0                      WHITE     NORTHERN        MEDFIELD      STREET
# 1  BLACK_OR_AFRICAN_AMERICAN    SOUTHEAST         BAYVIEW   APARTMENT
# 2  BLACK_OR_AFRICAN_AMERICAN      EASTERN   PENN-FALLSWAY      STREET
# 3                      WHITE     NORTHERN     ROLAND PARK      STREET
# 4  BLACK_OR_AFRICAN_AMERICAN     SOUTHERN  HOLLINS MARKET      GARAGE
#
#     Latitude  Longitude      Month  Hour        Daytime Age_Category  \
# ...

# %%
clm = cleverminer(df=df,proc='SD4ftMiner',
               quantifiers= {'Base1':400, 'Base2':400, 'Ratioconf' : 1.5},
               ante ={
                    'attributes':[
                        {'name': 'Description', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'Weapon', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'Gender', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'Age_Category', 'type': 'subset', 'minlen': 1, 'maxlen':1},
                        {'name': 'Police_in_neigh', 'type': 'subset', 'minlen': 1, 'maxlen': 1}
                    ], 'minlen':1, 'maxlen':5, 'type':'con'},
               succ ={
                    'attributes':[
                        {'name': 'Daytime_num', 'type': 'rcut', 'minlen': 1, 'maxlen': 2}
                    ], 'minlen':1, 'maxlen':1, 'type':'con'},
               frst ={
                    'attributes':[
                        {'name': 'Old_District', 'type': 'subset', 'minlen': 1, 'maxlen': 1}
                    ], 'minlen':1, 'maxlen':1, 'type':'con'},
               scnd ={
                    'attributes':[
                        {'name': 'Old_District', 'type': 'subset', 'minlen': 1, 'maxlen': 1}
                    ], 'minlen':1, 'maxlen':1, 'type':'con'}
               )


clm.print_summary()
clm.print_rulelist()
clm.print_rule(1)
# Out:
# Cleverminer version 1.0.11.
# Starting data preparation ...
# Automatically reordering numeric categories ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  SD4ftMiner
# Starting to mine rules.
#   0%|                                                    |Elapsed Time: 0:00:00
#   0%|                                                    |Elapsed Time: 0:00:00
#   0%|                                                    |Elapsed Time: 0:00:00
#   0%|                                                    |Elapsed Time: 0:00:00
#   0%|                                                    |Elapsed Time: 0:00:00
#   0%|                                                    |Elapsed Time: 0:00:00
#   0%|                                                    |Elapsed Time: 0:00:00
#   0%|                                                    |Elapsed Time: 0:00:00
# ...
